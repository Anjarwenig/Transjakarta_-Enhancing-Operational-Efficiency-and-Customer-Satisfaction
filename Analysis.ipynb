# %% [markdown]
# <h2 style='text-align:center; color:blue'><b> [ Transjakarta: Enhancing Operational Efficiency and Customer Satisfaction]</b></h1>
# <h5 style="text-align: center;"> [Galuh Anjarweni]</h2>

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 1 |</span><span style='color:darkblue'> Introduction</span></b>
#
# ____
#
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> About the Company</span></b>
# <div class="alert alert-block alert-success">
#
# Transjakarta has a long history of changing Jakarta's public transportation system. Founded in 2004 as the first bus rapid transit (BRT) system in Southeast Asia, it initially aimed to alleviate traffic congestion and pollution with one corridor. Transjakarta has grown over time to include various routes, catering to millions of passengers every day.
#
# Our goal is to offer secure, effective, and cost-friendly transportation, improving the daily lives of Jakarta residents. Our guiding principles include dependability, availability, and environmental responsibility. We aim to become a top-quality public transportation system, recognized for efficient operations, excellent customer service, and sustainable urban mobility. Our goal is to grow and update by incorporating cutting-edge technologies and environmentally conscious methods.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Business Context</span></b>
# <div class="alert alert-block alert-success">
#
# Business environment for Transjakarta
#
# The public transportation sector is vital for urban mobility in Jakarta, and Transjakarta has been important since it began in 2004. Major trends consist of rising urbanization, the demand for eco-friendly transportation options, and the incorporation of cutting-edge technologies to improve service efficiency and customer satisfaction.
#
# In this rapidly changing setting, Transjakarta encounters competition from various other public transportation options and private car services. In order to stay ahead of the competition, we prioritize the expansion of our network, upgrading our fleet, and utilizing data-driven insights to enhance operations and address the changing demands of Jakarta's residents.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Business Task</span></b>

# %% [markdown]
# <a id="business-task"></a>
# <div class="alert alert-block alert-success">
# <b><span style='color:darkblue'>Business Task</span></b>
#
# Business Task for Transjakarta: Enhancing Operational Efficiency and Customer Satisfaction
#
# **Problem Statement:**
#
# Transjakarta faces significant challenges with route efficiency and congestion, particularly during peak hours. These issues lead to extended travel times, variability in trip durations, and decreased customer satisfaction. The goal of this analysis is to identify and address these inefficiencies to improve operational performance and enhance the overall customer experience.
#
# **Objectives:**
#
# - Improve Route Efficiency: Optimize routes to reduce travel times and congestion, particularly during peak hours.
# - Enhance Customer Satisfaction: Ensure more consistent and reliable travel times to improve the dependability of the service.
# - Increase Operational Performance: Identify and implement operational changes to better manage peak hour demand and reduce delays.
#
# **Key Questions:**
#
# - Which routes experience the highest congestion and longest travel times during peak hours?
# - What are the main causes of delays and extended travel times on these routes?
# - How does travel time variability affect customer satisfaction and service dependability?
# - What changes can be made to optimize route efficiency and manage peak hour demand more effectively?
#
# **Scope:**
#
# - **Time Frame**: Analysis will focus on April 2023 of operational data.
# - **Geographical Region**: All routes serviced by Transjakarta within Jakarta will be included.
# - **Data Sources**: Transjakarta Dummy dataset
# - **Exclusions**: The analysis will exclude external factors not directly controllable by Transjakarta, such as traffic accidents or road construction activities not routinely affecting the routes.
#
# **Success Criteria:**
#
# - **Reduced Travel Times**: Achieve a 10% reduction in average travel times on the most congested routes during peak hours.
# - **Increased Consistency**: Decrease the variability in travel times by 15%, ensuring more predictable and reliable service.
# - **Increased On-Time Performance**: Achieve a 15% improvement in on-time performance for buses on the most congested routes during peak hours.
# - **Operational Efficiency**: Implement at least three operational changes (e.g., adjusted bus schedules, route optimizations) that contribute to the improvements outlined above.
#
# This analysis will leverage data to provide actionable insights aimed at optimizing the efficiency of Transjakarta's routes, contributing to better service reliability, reduced operational costs, and enhanced passenger satisfaction.
# </div>

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Scenario</span></b>
# <div class="alert alert-block alert-success">
#
#
# Scenario for Transjakarta: Enhancing Transjakarta's Operational Efficiency and Customer Satisfaction
#
# The primary stakeholders for this analysis include:
#
# - **Pemprov DKI Jakarta:** The provincial government overseeing Transjakarta's operations and funding, ensuring alignment with public transportation policies and strategic goals.
# - **Dinas Perhubungan (Dishub) Provinsi DKI Jakarta:** Responsible for regulatory compliance and overall transport policy, ensuring the recommendations adhere to existing regulations and policies.
# - **Welfizon Yuza, Direktur Utama:** Oversees the overall strategic direction of Transjakarta and ensures the implementation of efficiency improvements aligns with organizational goals.
# - **Daud Joseph, Direktur Operasional & Keselamatan:** Oversees and improves operational efficiency and safety, focusing on reducing travel times and variability.
# - **Raditya Maulana Rusdi, Direktur Sistem Teknologi Informasi dan Pelayanan:** Utilizes insights to enhance route planning and scheduling systems, leveraging technology for optimization.
# - **Operational Planning Team:** Involved in route management and optimization efforts, implementing changes based on analysis findings.
#
# We assume that the available data from January to June 2023 is accurate and comprehensive. Additionally, we assume that external factors such as economic conditions and regulatory policies remain stable during the analysis period. The focus is on identifying inefficiencies in current routes and schedules to improve overall route efficiency. This analysis will be conducted under the framework of the regulations set by Peraturan Gubernur (Pergub) DKI No. 48 Tahun 2006
#
# Assumptions for the Analysis:
#
# - **Data Integrity:** The available data from January to June 2023 is assumed to be accurate and comprehensive, providing a reliable basis for analysis.
# - **External Stability:** It is assumed that external factors such as economic conditions and regulatory policies will remain stable during the analysis period, allowing for a focused analysis on internal operational efficiencies.
# - **Regulatory Framework:** The analysis will be conducted under the framework of the regulations set by Peraturan Gubernur (Pergub) DKI No. 48 Tahun 2006, ensuring compliance with existing policies.
#
# Focus:
#
# The analysis will concentrate on identifying inefficiencies in current routes and schedules to improve overall route efficiency. This includes examining peak hour congestion, travel time variability, and underutilized routes to propose actionable recommendations for optimizing Transjakarta’s operational performance and customer satisfaction.
#
# </div>

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 2 |</span><span style='color:darkblue'> Data Examination</span></b>

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Size: Amount and Range</span></b>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Import all needed libraries

# %%
#Import Library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopy.distance as dis

# %% [markdown]
# <div class="alert alert-block alert-success">
# Step 1: Load dataset

# %%
df= pd.read_csv('Transjakarta.csv')
df.head()
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB   180062659848800      emoney   Bajragin Usada          M
# 1  LGXO740D2N47GZ  4885331907664776         dki     Gandi Widodo          F
# 2  DJWR385V2U57TO  4996225095064169         dki    Emong Wastuti          F
# 3  JTUZ800U7C86EH      639099174703       flazz     Surya Wacana          F
# 4  VMLO535V7F95NJ      570928206772       flazz  Embuh Mardhiyah          M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0              2008          5                     Matraman Baru - Ancol
# 1              1997         6C  Stasiun Tebet - Karet via Patra Kuningan
# 2              1992        R1A                        Pantai Maju - Kota
# 3              1978        11D       Pulo Gebang - Pulo Gadung 2 via PIK
# 4              1982         12                     Tanjung Priok - Pluit
#
# ...

# %% [markdown]
# | Field Name         | Description                                                      |
# |--------------------|------------------------------------------------------------------|
# | **transID**        | Unique transaction id for every transaction                      |
# | **payCardID**      | Customers main identifier. The card used as a ticket for entrance and exit. |
# | **payCardBank**    | Customers card bank issuer name                                  |
# | **payCardName**    | Customers name that is embedded in the card.                     |
# | **payCardSex**     | Customers sex that is embedded in the card                       |
# | **payCardBirthDate** | Customers birth year                                          |
# | **corridorID**     | Corridor ID / Route ID as key for route grouping.                |
# | **corridorName**   | Corridor Name / Route Name contains Start and Finish for each route. |
# | **direction**      | 0 for Go, 1 for Back. Direction of the route.                    |
# | **tapInStops**     | Tap In (entrance) Stops ID for identifying stops name            |
# | **tapInStopsName** | Tap In (entrance) Stops Name where customers tap in.             |
# | **tapInStopsLat**  | Latitude of Tap In Stops                                         |
# | **tapInStopsLon**  | Longitude of Tap In Stops                                        |
# | **stopStartSeq**   | Sequence of the stops, 1st stop, 2nd stops etc. Related to direction. |
# | **tapInTime**      | Time of tap in. Date and time                                    |
# | **tapOutStops**    | Tap Out (Exit) Stops ID for identifying stops name               |
# | **tapOutStopsName**| Tap out (exit) Stops Name where customers tap out.               |
# | **tapOutStopsLat** | Latitude of Tap Out Stops                                        |
# | **tapOutStopsLon** | Longitude of Tap Out Stops                                       |
# | **stopEndSeq**     | Sequence of the stops, 1st stop, 2nd stops etc. Related to direction. |
# | **tapOutTime**     | Time of tap out. Date and time                                   |
# | **payAmount**      | The number of what customers pay. Some are free. Some not.       |

# %% [markdown]
# <div class="alert alert-block alert-success">Data Size and Shape

# %%
print('\033[1;94mSummary statistics for numerical columns\033[0m')
df.describe()
# Out:
# Summary statistics for numerical columns
#           payCardID  payCardBirthDate     direction  tapInStopsLat  \
# count  3.790000e+04      37900.000000  37900.000000   37900.000000
# mean   4.250060e+17       1990.089314      0.500633      -6.214838
# std    1.321699e+18         13.051482      0.500006       0.057911
# min    6.040368e+10       1946.000000      0.000000      -6.394973
# 25%    1.800442e+14       1982.000000      0.000000      -6.245863
# 50%    3.507947e+15       1990.000000      1.000000      -6.214587
# 75%    4.699023e+15       2001.000000      1.000000      -6.175528
# max    4.997694e+18       2012.000000      1.000000      -6.089429
#
#        tapInStopsLon  stopStartSeq  tapOutStopsLat  tapOutStopsLon  \
# count   37900.000000  37900.000000    36556.000000    36556.000000
# mean      106.841554     13.572480       -6.214651      106.841233
# std         0.060369     12.237623        0.059022        0.060999
# ...

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Condition: Quality and Representativeness</span></b>

# %%
print('\033[1;94mRange of Values for Each Column\033[0m')

print(f'Number of rows and columns: {df.shape}')
pd.DataFrame({
    'Type': df.dtypes,
    'N/A (%)': df.isna().mean() * 100,
    'Unique': df.nunique(),
    'Sample': [df[col].unique() for col in df.columns]
})
# Out:
# Range of Values for Each Column
# Number of rows and columns: (37900, 22)
#                      Type   N/A (%)  Unique  \
# transID            object  0.000000   37900
# payCardID           int64  0.000000    2000
# payCardBank        object  0.000000       6
# payCardName        object  0.000000    1993
# payCardSex         object  0.000000       2
# payCardBirthDate    int64  0.000000      67
# corridorID         object  3.316623     221
# corridorName       object  5.092348     216
# direction         float64  0.000000       2
# tapInStops         object  3.200528    2570
# tapInStopsName     object  0.000000    2602
# tapInStopsLat     float64  0.000000    2587
# tapInStopsLon     float64  0.000000    2458
# stopStartSeq        int64  0.000000      67
# tapInTime          object  0.000000   37079
# tapOutStops        object  6.039578    2230
# tapOutStopsName    object  3.546174    2248
# tapOutStopsLat    float64  3.546174    2237
# tapOutStopsLon    float64  3.546174    2139
# ...

# %% [markdown]
# **Summary of unclean data of important columns**
#
#
# [ ] corridorName    : 5.09 % missing values
#
# [ ] tapInStops      : 3.2 % missing values
#
# [ ] tapOutStops     : 6% missing values
#
# [ ] tapOutStopsName : 3.5% missing values
#
# [ ] tapOutStopsLat  : 3.5% missing values
#
# [ ] tapOutStopsLon  : 3.5% missing values
#
# [ ] stopEndSeq      : 3.5% missing values
#
# [ ] tapInTime       : convert to datetime data type
#
# [ ] tapOutTime      : convert to datetime data type. Handle 3.5 % missing value
#
# [ ] payAmount       : 2.6%

# %% [markdown]
# <div class="alert alert-block alert-success">Examine duplicated rows

# %%
print('\033[1;94mChecking duplicated rows\033[0m')
n = df[df.duplicated()].shape[0]
print(f'There are {n} ({round(n/len(df)*100, 2)}%) row(s) of duplicated data.')
# Out:
# Checking duplicated rows
# There are 0 (0.0%) row(s) of duplicated data.

# %% [markdown]
# <div class="alert alert-block alert-success">Examine and Convert Data Types

# %%
df.dtypes

import pandas as pd

# Convert datetime
df['tapInTime'] = pd.to_datetime(df['tapInTime'])
df['tapOutTime'] = pd.to_datetime(df['tapOutTime'])

# Convert to categorical
df['payCardSex'] = df['payCardSex'].astype('category')
df['corridorName'] = df['corridorName'].astype('category')

# Convert geospatial data to float32
df['tapInStopsLat'] = df['tapInStopsLat'].astype('float32')
df['tapInStopsLon'] = df['tapInStopsLon'].astype('float32')
df['tapOutStopsLat'] = df['tapOutStopsLat'].astype('float32')
df['tapOutStopsLon'] = df['tapOutStopsLon'].astype('float32')

# %%
# Check the data types of all columns
print(df.dtypes)
# Out:
# transID                     object
# payCardID                    int64
# payCardBank                 object
# payCardName                 object
# payCardSex                category
# payCardBirthDate             int64
# corridorID                  object
# corridorName              category
# direction                  float64
# tapInStops                  object
# tapInStopsName              object
# tapInStopsLat              float32
# tapInStopsLon              float32
# stopStartSeq                 int64
# tapInTime           datetime64[ns]
# tapOutStops                 object
# tapOutStopsName             object
# tapOutStopsLat             float32
# tapOutStopsLon             float32
# stopEndSeq                 float64
# tapOutTime          datetime64[ns]
# payAmount                  float64
# dtype: object

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Size: Amount and Range</span></b>

# %% [markdown]
# <div class="alert alert-block alert-success">Frequency Distribution

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Condition: Quality and Representativeness</span></b>
#
# Undiscovered and unresolved issues around the quality of the data will undermine the trust in and the accuracy of your work. We will need to discover and address these issues during this stage of the process.

# %% [markdown]
# - Check for Missing Values

# %%
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
print("Missing Values and Their Percentage:")
print(missing_data)
# Out:
# Missing Values and Their Percentage:
#                   Missing Values  Percentage
# transID                        0    0.000000
# payCardID                      0    0.000000
# payCardBank                    0    0.000000
# payCardName                    0    0.000000
# payCardSex                     0    0.000000
# payCardBirthDate               0    0.000000
# corridorID                  1257    3.316623
# corridorName                1930    5.092348
# direction                      0    0.000000
# tapInStops                  1213    3.200528
# tapInStopsName                 0    0.000000
# tapInStopsLat                  0    0.000000
# tapInStopsLon                  0    0.000000
# stopStartSeq                   0    0.000000
# tapInTime                      0    0.000000
# tapOutStops                 2289    6.039578
# tapOutStopsName             1344    3.546174
# tapOutStopsLat              1344    3.546174
# tapOutStopsLon              1344    3.546174
# ...

# %% [markdown]
# - checking Anomaly on tapouttime

# %%
#reload the dataset and create temporary dataframe called quality check
quality_check= pd.read_csv('Transjakarta.csv')


'''Examine inconsistencies of text based column for capitalization and naming convenssion
Check the unique values in corridorName and paycardname to Identify capitalization inconsistencies'''

check_coridorname= quality_check['corridorName'].dropna().unique()
check_paycard_names= quality_check['payCardName'].dropna().unique()

check_coridorname, check_paycard_names
# Out:
# (array(['Matraman Baru - Ancol',
#         'Stasiun Tebet - Karet via Patra Kuningan', 'Pantai Maju - Kota',
#         'Pulo Gebang - Pulo Gadung 2 via PIK', 'Tanjung Priok - Pluit',
#         'Cibubur - Balai Kota', 'Kalibata - Kuningan',
#         'Bekasi Barat - Kuningan', 'Rempoa - Blok M',
#         'Kampung Melayu - Tanah Abang via Cikini', 'BKN - Blok M',
#         'PGC 2 - Grogol 2', 'Pulo Gadung 2 - Tosari',
#         'Pasar Minggu - Jagakarsa', 'Ciputat - Kampung Rambutan',
#         'Ciledug - Tendean', 'Kebayoran Lama - Jelambar',
#         'Pinang Ranti - Pluit', 'Terminal Tanjung Priok - Ancol Barat',
#         'Poris Plawad - Bundaran Senayan', 'Cililitan - Condet',
#         'Ragunan - Gelora Bung Karno',
#         'Kampung Melayu - Pulo Gebang via BKT',
#         'Kampung Melayu - Duren Sawit', 'Pulo Gebang - Matraman',
#         'Pesanggrahan - Blok M', 'Rusun Flamboyan - Cengkareng',
#         'Blok M - Kota', 'Kampung Rambutan - Ragunan', 'Senen - Blok M',
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Summary:</b><br>
#
# - The corridorNames appear to be consostent in term of capitalization. Each word starts with a capital letter
# - The PaycardNAmes appear to be consistently capitalized, indicates first name and last name

# %%
#use temporary dataframe quality_check

#convert tap in and tap out time into datetime type 
quality_check['tapInTime']=pd.to_datetime(quality_check['tapInTime'])
quality_check['tapOutTime']=pd.to_datetime(quality_check['tapOutTime'])

#check if there is invalid time entries
invalid_time= quality_check[quality_check['tapInTime']>quality_check['tapOutTime']]

invalid_time
# Out:
# Empty DataFrame
# Columns: [transID, payCardID, payCardBank, payCardName, payCardSex, payCardBirthDate, corridorID, corridorName, direction, tapInStops, tapInStopsName, tapInStopsLat, tapInStopsLon, stopStartSeq, tapInTime, tapOutStops, tapOutStopsName, tapOutStopsLat, tapOutStopsLon, stopEndSeq, tapOutTime, payAmount]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Limitation:</b><br>
#
# The dataset, which only covers April 2023, is likely to overlook broader seasonal transit trends, limiting its year-round relevance. It accurately represents card-based transactions, but it may not capture temporal fluctuations well, particularly if data on specific routes or times is unavailable. This could skew insights about network efficiency, indicating the need for more data collection at different periods and possibly integration with additional traffic or event-related data to improve representation.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 3 |</span><span style='color:darkblue'> Data Transformation</span></b>
#
# ____
#
# Before making any modifications, make sure to  keep a copy of the original dataset. This provides a reference point to compare against or refer to if necessary.

# %%
#back up the original dataset df into orginaldf
original_df= df.copy()

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Cleaning</span></b>
#
# We focus only on calumns that we use on our analysis

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Summary of unclean data of important columns:</b><br>
#
#
#
# [ ] corridorName    : 5.09 % missing values
#
# [ ] tapInStops      : 3.2 % missing values
#
# [ ] tapOutStops     : 6% missing values. We will not need this column as tapOutStopsName is more representative
#
# [ ] tapOutStopsName : 3.5% missing values
#
# [ ] tapOutStopsLat  : 3.5% missing values
#
# [ ] tapOutStopsLon  : 3.5% missing values
#
# [ ] stopEndSeq      : 3.5% missing values
#
# [ ] tapInTime       : convert to datetime data type
#
# [ ] tapOutTime      : convert to datetime data type. Handle 3.5 % missing value
#
# [ ] payAmount       : 2.6%

# %% [markdown]
# - Handle corridorName missing values

# %%
# create temporary dataset for mappping
mapping_df = pd.read_csv('Transjakarta.csv')

#create mapping from corridorID to corridorname from not-null entries
corridor_mapping= mapping_df.dropna(subset=['corridorID', 'corridorName'])
corridor_mapping= corridor_mapping.drop_duplicates(subset=['corridorID']).set_index('corridorID')['corridorName'].to_dict()

#check mapping
print(corridor_mapping)



'''Use mapping to fill the corridorName based on corridorID'''

df['corridorName']=df.apply(lambda row: corridor_mapping[row['corridorID']]if pd.isna(row['corridorName']) and row['corridorID'] in corridor_mapping else row['corridorName'],
    axis=1)
remainingNull_cn= df['corridorName'].isnull().sum()

print(f'Remaining nulls in corridorName after mapping is {remainingNull_cn} from 37900 entries which is only 2,9% or unsignificant amount, so it is safe to drop it')


'''handeling coridorName using  combined tapIn and tapoutstop identifier '''

#create a combined tapIn and tapoutstop identifier
df['combined_stops']=df['tapInStops'] + '-' + df['tapOutStops']

#Mapping based on not null data on corridorName
stop_mapping= df.dropna(subset=['corridorName']).groupby('combined_stops')['corridorName'].agg(lambda x: x.mode()[0] if not x.empty else np.nan).to_dict()

#apply the mapping to fill the remaining missing routeName
df['corridorName']=df.apply(lambda row: stop_mapping.get(row['combined_stops'], row['corridorName'])if pd.isna(row['corridorName']) else row['corridorName'], axis=1)

#check the remaining null
rM_null=df['corridorName'].isnull().sum()
print(f'the remaining null value  using  combined tapIn and tapoutstop identifier is {rM_null} from {remainingNull_cn}. The count is unsignificant so we can drop it')

#drop the remaining
df.dropna(subset=['corridorName'], inplace=True)
n_cm= df['corridorName'].isnull().sum()

print(f'the remaining null value on corridorName is {n_cm}')
# Out:
# {'5': 'Matraman Baru - Ancol', '6C': 'Stasiun Tebet - Karet via Patra Kuningan', 'R1A': 'Pantai Maju - Kota', '11D': 'Pulo Gebang - Pulo Gadung 2 via PIK', '12': 'Tanjung Priok - Pluit', '1T': 'Cibubur - Balai Kota', 'JAK.18': 'Kalibata - Kuningan', 'B14': 'Bekasi Barat - Kuningan', '1Q': 'Rempoa - Blok M', '5M': 'Kampung Melayu - Tanah Abang via Cikini', 'M7B': 'BKN - Blok M', '9A': 'PGC 2 - Grogol 2', '4': 'Pulo Gadung 2 - Tosari', 'JAK.46': 'Pasar Minggu - Jagakarsa', 'S22': 'Ciputat - Kampung Rambutan', '13': 'Ciledug - Tendean', '9E': 'Kebayoran Lama - Jelambar', 'M9': 'Pinang Ranti - Pluit', 'JAK.88': 'Terminal Tanjung Priok - Ancol Barat', 'T11': 'Poris Plawad - Bundaran Senayan', 'JAK.16': 'Cililitan - Condet', '6V': 'Ragunan - Gelora Bung Karno', '11Q': 'Kampung Melayu - Pulo Gebang via BKT', 'JAK.02': 'Kampung Melayu - Duren Sawit', '11': 'Pulo Gebang - Matraman', '1C': 'Pesanggrahan - Blok M', '3B': 'Rusun Flamboyan - Cengkareng', 'M1': 'Blok M - Kota', '7E': 'Kampung Ramb
# ...

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (37726, 23)

# %% [markdown]
# **Summary of unclean data of important columns**
#
#
# [x] corridorName    : 5.09 % missing values
#
# [ ] tapOutStops     : 6% missing values. We will not need this column as tapOutStopsName is more representative
#
# [ ] tapOutStopsName : 3.5% missing values
#
# [ ] tapOutStopsLat  : 3.5% missing values
#
# [ ] tapOutStopsLon  : 3.5% missing values
#
# [ ] stopEndSeq      : 3.5% missing values
#
# [ ] tapInTime       : convert to datetime data type
#
# [ ] tapOutTime      : convert to datetime data type. Handle 3.5 % missing value
#
# [ ] payAmount       : 2.6%

# %% [markdown]
# - Handeling TapoutStopName missing values

# %%
#check missing values count
df['tapOutStopsName'].isnull().sum()
# Out:
# 1297

# %%
''' The columns that are associated with the tapoutname are tapOutStops, tapOutStopsLat, tapOutStopsLon, stopEndSeq  and tapOutTime  
where each of them is null where the tapoutname is null, while filling them withouth matching with the corridorname will create anomalies.
Therefore it is better to drop them'''

df.dropna(subset=['tapOutStopsName'], inplace=True)


n_ton= df['tapOutStopsName'].isnull().sum()

print(f'the remaining null value on tapOutStopsName  is {n_ton}')
# Out:
# the remaining null value on tapOutStopsName  is 0

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (36429, 23)

# %%
df.isnull().sum()
# Out:
# transID                0
# payCardID              0
# payCardBank            0
# payCardName            0
# payCardSex             0
# payCardBirthDate       0
# corridorID          1078
# corridorName           0
# direction              0
# tapInStops          1146
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops          913
# tapOutStopsName        0
# tapOutStopsLat         0
# tapOutStopsLon         0
# stopEndSeq             0
# tapOutTime             0
# payAmount            968
# combined_stops      2035
# dtype: int64

# %% [markdown]
# **Summary of the remaining unclean data of important columns**
#
#
# [x] corridorName    : 5.09 % missing values
#
# [x] tapOutStops     : 6% missing values. We will not need this column as tapOutStopsName is more representative
#
# [x] tapOutStopsName : 3.5% missing values
#
# [x] tapOutStopsLat  : 3.5% missing values
#
# [x] tapOutStopsLon  : 3.5% missing values
#
# [x] stopEndSeq      : 3.5% missing values
#
# [x] tapOutTime      : convert to datetime data type. Handle 3.5 % missing value
#
# [ ] payAmount       : 2.6%

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:darkblue'> Data Creating and Data Consolidating</span></b>
#
#
#  <b><span style='color:darkblue'> tap In and Tap Out Hour</span></b>
#
#
# Adding columns that extract certain parts of tapInTime and tapOutTime simplifies assessments of time-based trends, peak hour usage, and can assist detect patterns connected to transportation demand at different times of day. This approach is especially useful for assessing traffic movement and improving bus schedules to better meet passenger needs.

# %%
# Extract hours from 'tapInTime' and 'tapOutTime'
df['tapInHour'] = df['tapInTime'].dt.hour
df['tapOutHour'] = df['tapOutTime'].dt.hour

# check the new columns
print(df[['tapInHour', 'tapOutHour']].head(2))
# Out:
#    tapInHour  tapOutHour
# 0          5           6
# 1          5           6

# %% [markdown]
#  <b><span style='color:darkblue'>Distance</span></b>
#
# Creating a column that calculates the distance between tapInStops and tapOutStops using latitude and longitude coordinates can provide useful insights on travel patterns and trip lengths, as well as potentially give insights in route optimization and service reliability. Distances can be calculated using coordinates to better understand geographical trends and riders' spatial behavior.

# %%
# Function to calculate Haversine distance
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in kilometers
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2)**2
    return R * 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a)) * 1000  # for meters

df['distance'] = df.apply(lambda x: haversine(x['tapInStopsLat'], x['tapInStopsLon'], x['tapOutStopsLat'], x['tapOutStopsLon']), axis=1)

df['distance'] = np.floor(df['distance'])


# check the new columns
print(df[['distance']].head(2))
# Out:
#    distance
# 0    2514.0
# 1    2020.0

# %% [markdown]
#  <b><span style='color:darkblue'>TravelTime</span></b>
#
# Creating travelTime column help to study how long travels take between points, which is essential for evaluating the transit system's efficiency and efficacy.
# Calculating journey time also paves the way for subsequent investigations, such as predicting traffic speeds and assessing service reliability.

# %%
# Calculate travel time in minutes
df['travelTime'] = (df['tapOutTime'] - df['tapInTime']).dt.total_seconds() / 60
df['travelTime'] = np.floor(df['travelTime'])

# check the new columns
print(df[['travelTime']].head(2))
# Out:
#    travelTime
# 0        39.0
# 1        57.0

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (36429, 27)

# %% [markdown]
#  <b><span style='color:darkblue'>TravelSpeed</span></b>
#
# Adding a travelspeed column helps to track route efficiency, identify sluggish parts, and improve service planning.
# By examining speed data, transit operators may increase customer satisfaction, make data-driven adjustments, and strategically expand infrastructure,
# improving overall system performance and service quality.

# %%
#calculate the speed in km/hour
df['travelSpeed_KmpH'] = (df['distance'] / 1000) / (df['travelTime'] / 60)

#display the new columns
print(df[['distance', 'travelTime', 'travelSpeed_KmpH']].head())
# Out:
#    distance  travelTime  travelSpeed_KmpH
# 0    2514.0        39.0          3.867692
# 1    2020.0        57.0          2.126316
# 2      80.0        51.0          0.094118
# 3    1456.0        43.0          2.031628
# 4    8721.0        39.0         13.416923

# %%
df[['distance', 'travelTime', 'travelSpeed_KmpH']].describe()
# Out:
#            distance    travelTime  travelSpeed_KmpH
# count  36429.000000  36429.000000      36429.000000
# mean    2756.677537     71.634687          2.866433
# std     3258.034364     28.061717          4.241851
# min        0.000000     15.000000          0.000000
# 25%      740.000000     51.000000          0.657273
# 50%     1709.000000     71.000000          1.515484
# 75%     3374.000000     95.000000          3.298889
# max    22651.000000    179.000000         84.941250

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (36429, 28)

# %% [markdown]
# There are distance that are 0. Check how large the entry is

# %%
#checking zero distance count
zero_distance_count = (df['distance'] == 0).sum()

print(zero_distance_count)
# Out:
# 20

# %% [markdown]
# The number of entries is not significant, so we can safely drop it

# %%
# Filter out rows where the distance is zero and update the same DataFrame
df = df[df['distance'] != 0]

# Optionally, reset the index if you want a clean, sequential index
df.reset_index(drop=True, inplace=True)

# Verify the operation by checking if there are any rows with zero distance
ZeroD_count = (df['distance'] == 0).sum()
print(f"Number of rows with zero distance after modification: {ZeroD_count}")
# Out:
# Number of rows with zero distance after modification: 0

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (36409, 28)

# %% [markdown]
# - Check the current statistics

# %%
df[['distance', 'travelTime', 'travelSpeed_KmpH']].describe()
# Out:
#            distance    travelTime  travelSpeed_KmpH
# count  36409.000000  36409.000000      36409.000000
# mean    2758.191821     71.623802          2.868008
# std     3258.288222     28.062210          4.242483
# min       12.000000     15.000000          0.006486
# 25%      741.000000     51.000000          0.657931
# 50%     1711.000000     71.000000          1.517586
# 75%     3374.000000     95.000000          3.300000
# max    22651.000000    179.000000         84.941250

# %% [markdown]
#  <b><span style='color:darkblue'>TravelSpeed categories</span></b>
#
# Categorizing travel speed simplifies data analysis and communication, aids in identifying underperforming routes for operational improvements, and makes it easier to create and monitor performance goals for ongoing development.

# %%
#Create speed category function
def Speeed_categories(speed):
    if speed > 50:  # assuming speed is in km/h
        return 'Excellent'
    elif speed > 30:
        return 'Good'
    elif speed > 20:
        return 'Moderate'
    elif speed > 10:
        return 'Poor'
    else:
        return 'Very Poor'

# Assuming 'travelSpeedKmH' is the column with the travel speed data
df['speedCategory'] = df['travelSpeed_KmpH'].apply(Speeed_categories)

# Preview the new categorical data
print(df[['travelSpeed_KmpH', 'speedCategory']].head())
# Out:
#    travelSpeed_KmpH speedCategory
# 0          3.867692     Very Poor
# 1          2.126316     Very Poor
# 2          0.094118     Very Poor
# 3          2.031628     Very Poor
# 4         13.416923          Poor

# %% [markdown]
# Dropping Unecessary columns

# %%
#back up data with all columns
completed_column= df.copy()

# %%
# List of columns not necessary for the analysis
unneeded = [
    'transID', 'payCardID', 'payCardBank', 'payCardName',
    'payCardBirthDate', 'payAmount','corridorID','tapInStops', 'tapOutStops', 'payAmount', 'combined_stops', 'payCardSex'
]

# Drop the unnecessary columns from the copy
df.drop(columns=unneeded, inplace=True)

# Rename the column
df.rename(columns={'corridorName': 'routeName'}, inplace=True)

df.head(3)
# Out:
#                                   routeName  direction tapInStopsName  \
# 0                     Matraman Baru - Ancol        1.0      Pal Putih
# 1  Stasiun Tebet - Karet via Patra Kuningan        0.0     Kemenkes 2
# 2                        Pantai Maju - Kota        0.0   Gg. Kunir II
#
#    tapInStopsLat  tapInStopsLon  stopStartSeq           tapInTime  \
# 0      -6.184631     106.844017             7 2023-04-03 05:21:44
# 1      -6.228700     106.833023            13 2023-04-03 05:42:44
# 2      -6.133132     106.814346            38 2023-04-03 05:59:06
#
#          tapOutStopsName  tapOutStopsLat  tapOutStopsLon  stopEndSeq  \
# 0                Tegalan       -6.203101      106.857147        12.0
# 1    Sampoerna Strategic       -6.217152      106.818916        21.0
# 2  Simpang Kunir Kemukus       -6.133731      106.814751        39.0
#
#            tapOutTime  tapInHour  tapOutHour  distance  travelTime  \
# 0 2023-04-03 06:00:53          5           6    2514.0        39.0
# ...

# %%
print(f'Number of rows and columns: {df.shape}')
# Out:
# Number of rows and columns: (36409, 18)

# %% [markdown]
# Check the current conditions of the dataset

# %%
print('\033[1;94mRange of Values for Each Column\033[0m')

print(f'Number of rows and columns: {df.shape}')
pd.DataFrame({
    'Type': df.dtypes,
    'N/A (%)': df.isna().mean() * 100,
    'Unique': df.nunique(),
    'Sample': [df[col].unique() for col in df.columns]
})
# Out:
# Range of Values for Each Column
# Number of rows and columns: (36409, 18)
#                             Type  N/A (%)  Unique  \
# routeName                 object      0.0     216
# direction                float64      0.0       2
# tapInStopsName            object      0.0    2535
# tapInStopsLat            float32      0.0    2520
# tapInStopsLon            float32      0.0    2384
# stopStartSeq               int64      0.0      67
# tapInTime         datetime64[ns]      0.0   35657
# tapOutStopsName           object      0.0    2220
# tapOutStopsLat           float32      0.0    2209
# tapOutStopsLon           float32      0.0    2103
# stopEndSeq               float64      0.0      74
# tapOutTime        datetime64[ns]      0.0   35763
# tapInHour                  int32      0.0      17
# tapOutHour                 int32      0.0      20
# distance                 float64      0.0    2955
# travelTime               float64      0.0     158
# ...

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 4 |</span><span style='color:darkblue'> Data Exploration</span></b>

# %% [markdown]
# - Explore all squensial routes of each routename

# %%
# Ensure that sequence columns are integers for proper sorting
df['stopStartSeq'] = pd.to_numeric(df['stopStartSeq'], errors='coerce')
df['stopEndSeq'] = pd.to_numeric(df['stopEndSeq'], errors='coerce')

# Combining stop information into a single column for simplicity
df['CombinedStops'] = df.apply(lambda x: f"{x['tapInStopsName']} (Seq: {x['stopStartSeq']}) - {x['tapOutStopsName']} (Seq: {x['stopEndSeq']})", axis=1)

# Grouping by corridorName and direction, sorting by sequence, and aggregating combined stop names
route_details = df.groupby(['routeName', 'direction']).apply(
    lambda x: x.sort_values(['stopStartSeq', 'stopEndSeq'])
              .drop_duplicates(subset=['CombinedStops'])['CombinedStops'].tolist()
).reset_index(name='StopsList')

# Save or print the detailed route stops list
route_details.to_csv('Detailed_Route_Stops_List.csv', index=False)
route_details
# Out:
# C:\Users\galuh\AppData\Local\Temp\ipykernel_15044\3466145228.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   route_details = df.groupby(['routeName', 'direction']).apply(
#                                       routeName  direction  \
# 0        Andara - Stasiun Universitas Pancasila        0.0
# 1        Andara - Stasiun Universitas Pancasila        1.0
# 2                                  BKN - Blok M        0.0
# 3                                  BKN - Blok M        1.0
# 4                                BSD - Jelambar        0.0
# ..                                          ...        ...
# 427        Terminal Tanjung Priok - Ancol Barat        1.0
# ...

# %% [markdown]
# - Top 20 of the worst congested routes

# %%
# Calculate average travel time for each route across all hours
overall_stats = df.groupby('routeName').agg(
    Avg_TravelTime=('travelTime', 'mean')
).reset_index()

# Sort by average travel time and select the top 15 congested routes
overall_top15 = overall_stats.sort_values(by='Avg_TravelTime', ascending=False).head(25)

# Create a bar chart for the top 15 congested routes
plt.figure(figsize=(6, 4))
plt.barh(overall_top15['routeName'], overall_top15['Avg_TravelTime'], color='teal')
plt.title('Top 15 Most Congested Routes (Overall Average Travel Times)')
plt.xlabel('Average Travel Time (minutes)')
plt.ylabel('Route')
plt.gca().invert_yaxis()  # Invert y axis for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# This visualization help to understand overview of the most congested routes. It helps prioritize locations for improvement and complements other visualizations that focus on certain times or elements of congestion.

# %% [markdown]
# - Identifying peak hour trends

# %%
import matplotlib.pyplot as plt

# Create histograms for tap-in and tap-out hours to identify peak hours
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

# Histogram of tap-in hours
axes[0].hist(df['tapInHour'], bins=range(24), color='skyblue', edgecolor='black')
axes[0].set_title('Distribution of Tap-In Hours')
axes[0].set_xlabel('Hour of Day')
axes[0].set_ylabel('Frequency')
axes[0].set_xticks(range(0, 24, 1))

# Histogram of tap-out hours
axes[1].hist(df['tapOutHour'], bins=range(24), color='lightgreen', edgecolor='black')
axes[1].set_title('Distribution of Tap-Out Hours')
axes[1].set_xlabel('Hour of Day')
axes[1].set_ylabel('Frequency')
axes[1].set_xticks(range(0, 24, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Insight:
#
# The histograms for tap-in and tap-out hours provide insights into how transport usage is distributed throughout the day:
#
# - Tap-In Hours: There is an obvious peak in the morning hours, most likely due to the morning commute. This shows a high volume of traffic between 6 and 9 a.m.
# - Tap-Out Hours: Similar to tap-in hours, there is a noticeable rise in the evening, between 4 PM and 7 PM, which most likely corresponds to the evening rush hour.

# %% [markdown]
# - Identifying of top 10 of most congested routes

# %%
import matplotlib.pyplot as plt

# Define peak hours (commonly morning and evening rush hours)
morning_peak_hours = (7, 9)
evening_peak_hours = (17, 19)

# Filter data for peak hours
peak_hours_df = df[(df['tapInHour'].between(*morning_peak_hours)) | (df['tapInHour'].between(*evening_peak_hours))]

# Group by route and calculate average travel time and count of trips
peak_route_stats = peak_hours_df.groupby('routeName').agg(
    Average_Travel_Time=pd.NamedAgg(column='travelTime', aggfunc='mean'),
    Trip_Count=pd.NamedAgg(column='travelTime', aggfunc='count')
).sort_values(by='Average_Travel_Time', ascending=False)

# Plot the routes with the highest average travel times
plt.figure(figsize=(10, 8))
peak_route_stats.head(10)['Average_Travel_Time'].plot(kind='barh', color='skyblue')
plt.title('Top 10 Routes with Highest Average Travel Time During Peak Hours')
plt.xlabel('Average Travel Time (minutes)')
plt.ylabel('Route Name')
plt.gca().invert_yaxis()
plt.show()

peak_route_stats.head(10), peak_route_stats['Average_Travel_Time'].describe()
# Out:
# (                                      Average_Travel_Time  Trip_Count
#  routeName
#  Pesanggrahan - Blok M                           86.840000          50
#  Stasiun Tebet - Karet via Underpass             85.394495         109
#  Rusun Jati Rawasari - Senen                     84.867925          53
#  Rusun Cakung Barat - Pulo Gadung                83.962963          81
#  Kalideres - Bundaran HI via Veteran             83.944882         127
#  Pluit - Senen                                   83.836364          55
#  Kebayoran Lama - Tanah Abang                    83.616766         167
#  Grogol - Pos Pengumben via Slipi                83.384615          13
#  Terminal Kampung Melayu - Kapin Raya            83.317073          41
#  PGC 1 - Ancol                                   83.217391          46,
#  count    216.000000
#  mean      77.218767
#  std        3.412652
#  min       68.448276
#  25%       75.041615
#  50%       77.119643
#  75%       79.515522
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# Insight:
#
# During peak hours, the average travel time across all routes is around 77 minutes, with a 3.4-minute standard deviation.
# This implies that journey time varies moderately across different routes.

# %% [markdown]
# - Breakdown the most congested routes by morning peak hour and evening peakhour

# %%
# First, we need to filter data for morning and evening peaks as previously defined and calculate averages
morning_peak = df[(df['tapInHour'] >= 6) & (df['tapInHour'] <= 9)]
evening_peak = df[(df['tapInHour'] >= 16) & (df['tapInHour'] <= 19)]

# Calculate average travel time for each route during morning and evening peaks
morning_peak_stats = morning_peak.groupby('routeName').agg(
    Avg_TravelTime_morning=('travelTime', 'mean')
).reset_index()

evening_peak_stats = evening_peak.groupby('routeName').agg(
    Avg_TravelTime_evening=('travelTime', 'mean')
).reset_index()

# Merge the morning and evening stats for comparative analysis
congestion_analysis = pd.merge(morning_peak_stats, evening_peak_stats, on='routeName', how='outer')

# Sort by morning travel times for the top 10 congested routes
congestion_analysis = congestion_analysis.sort_values(by='Avg_TravelTime_morning', ascending=False).head(10)

# Data preparation for the visualization
morning_peak_data = congestion_analysis[['routeName', 'Avg_TravelTime_morning']]
evening_peak_data = congestion_analysis[['routeName', 'Avg_TravelTime_evening']]

# Creating the bar charts
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 6), sharex=True)

# Morning Peak Travel Times
axes[0].barh(morning_peak_data['routeName'], morning_peak_data['Avg_TravelTime_morning'], color='skyblue')
axes[0].set_title('Morning Peak Travel Times (6-9 AM)')
axes[0].set_xlabel('Average Travel Time (minutes)')
axes[0].invert_yaxis()  # Invert y axis for better readability

# Evening Peak Travel Times
axes[1].barh(evening_peak_data['routeName'], evening_peak_data['Avg_TravelTime_evening'], color='salmon')
axes[1].set_title('Evening Peak Travel Times (4-7 PM)')
axes[1].set_xlabel('Average Travel Time (minutes)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Insights from the Peak Travel Time Visualization:</b><br>
#
# Morning Peak Travel Times (6–9 AM)
#
# - Kampung Rambutan - Blok M has the longest average travel time during morning peak hours, indicating heavy congestion and delays.
# - Term. Pulo Gadung - Lampiri: The long journey duration suggests serious early traffic problems.
#
#
# Evening Peak Travel Times (4–7 PM)
# - Pinang Ranti - Pluit has the longest average travel time during evening peak hours, indicating substantial congestion.
# - Gondangdia - Senen and Cibubur Junction - Blok M both exhibit extended journey times, implying heavy evening traffic congestion.
#
# Implications:
# - Route-Specific Congestion: The routes with the longest travel times during peak hours, such as Kampung Rambutan - Blok M and Pinang Ranti - Pluit, are critical areas for intervention to reduce congestion.
# - Time-Specific Issues: Some routes experience more severe congestion in the morning (e.g., Kampung Rambutan - Blok M), while others are worse in the evening (e.g., Pinang Ranti - Pluit). Efficiency Opportunities: Routes that consistently have shorter travel times during peak hours could be used as benchmarks or further modified to manage more traffic efficiently.

# %% [markdown]
# - Analyzing the link between distance, speed, and travel time for the most congested routes.
#
# Next, investigate the variation in journey times across these routes to evaluate how it may effect customer satisfaction and service dependability.

# %%
# Analyze correlation between distance, speed, and travel time for the top congested routes
top_congested_routes = peak_route_stats.head(10).index
congested_routes_df = peak_hours_df[peak_hours_df['routeName'].isin(top_congested_routes)]

# Correlation matrix
correlation_matrix = congested_routes_df[['distance', 'travelTime', 'travelSpeed_KmpH']].corr()

# Plotting the correlation matrix
plt.figure(figsize=(8, 6))
plt.matshow(correlation_matrix, fignum=1, cmap='coolwarm')
plt.xticks(range(correlation_matrix.shape[1]), correlation_matrix.columns, rotation=45)
plt.yticks(range(correlation_matrix.shape[1]), correlation_matrix.columns)
plt.colorbar()
plt.title('Correlation Matrix for Distance, Travel Time, and Speed', pad=20)
plt.show()

correlation_matrix
# Out:
#                   distance  travelTime  travelSpeed_KmpH
# distance          1.000000    -0.02722          0.800936
# travelTime       -0.027220     1.00000         -0.386410
# travelSpeed_KmpH  0.800936    -0.38641          1.000000

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Corelation analysis:
#
# - Distance and speed show a substantial positive association (r = 0.80). This suggests that buses travel faster on longer routes, most likely due to stretches with greater speeds.
# - Distance and trip time show a weak negative connection (r = -0.03). This suggests that travel time on these routes does not rise considerably with distance, maybe due to frequent pauses or congestion.
# - Speed and journey time have a modest negative association (r = -0.39), indicating that lower speeds lead to longer travel times, as expected.
#
# Interpretation
# - Speed vs. Distance: Although buses run faster on longer routes, this does not considerably reduce overall trip time due to traffic and frequent stops.
# - Speed vs. journey Time: Slower speeds result in longer journey times, pointing to potential operational improvements such as improving stop frequency or traffic flow management.

# %% [markdown]
# - Calculate the standard deviation of traveltimes for each route to better understand the consistency of travel experiences and how variability may impact customer satisfaction.

# %%
# Calculate variability (standard deviation) of travel times for the top congested routes
variability_stats = congested_routes_df.groupby('routeName')['travelTime'].agg(['mean', 'std']).sort_values(by='std', ascending=False)

# Plot the variability in travel times for the top congested routes
plt.figure(figsize=(10, 8))
variability_stats['std'].plot(kind='bar', color='orange')
plt.title('Variability in Travel Times for Top Congested Routes')
plt.xlabel('Route Name')
plt.ylabel('Standard Deviation of Travel Time (minutes)')
plt.xticks(rotation=45, ha='right')
plt.show()

variability_stats
# Out:
#                                            mean        std
# routeName
# Stasiun Tebet - Karet via Underpass   85.394495  26.908287
# Kebayoran Lama - Tanah Abang          83.616766  26.126139
# Pesanggrahan - Blok M                 86.840000  25.913010
# Terminal Kampung Melayu - Kapin Raya  83.317073  25.736588
# Rusun Cakung Barat - Pulo Gadung      83.962963  24.967701
# Rusun Jati Rawasari - Senen           84.867925  24.789916
# Pluit - Senen                         83.836364  23.830236
# Kalideres - Bundaran HI via Veteran   83.944882  23.293267
# PGC 1 - Ancol                         83.217391  23.213897
# Grogol - Pos Pengumben via Slipi      83.384615  14.688649

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Variability in Travel Time Analysis
#
# High variability Routes: Stasiun Tebet - Karet via Underpass and Kebayoran Lama - Tanah Abang exhibit significant unpredictability, with standard deviations around 27 minutes. This implies that travel times can vary greatly, resulting in unpredictable and frequently unsatisfactory experiences for tourists.
#
# Low variability. The route from Grogol to Pos Pengumben via Slipi has the least fluctuation, with a standard deviation of approximately 15 minutes, indicating more regular travel times.
#
# Observation: High mean travel times on these routes suggest congestion, but high standard deviations imply unstable travel times.

# %% [markdown]
# - Temporal Analysis
# Analyze hourly and daily travel times to identify peak congestion periods, guiding targeted interventions for improved traffic flow.

# %%
# Hourly trend analysis - average travel time by hour of the day
hourly_travel_times = df.groupby('tapInHour')['travelTime'].mean()

# Plotting the hourly average travel times
plt.figure(figsize=(12, 6))
hourly_travel_times.plot(kind='line', marker='o', linestyle='-', color='blue')
plt.title('Average Travel Time by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Travel Time (minutes)')
plt.grid(True)
plt.xticks(range(0, 24))  # Set x-ticks for every hour of the day
plt.show()

hourly_travel_times
# Out:
# tapInHour
# 5     42.544104
# 6     54.407374
# 7     69.197913
# 8     70.357117
# 9     69.870432
# 10    70.095070
# 11    66.701220
# 12    69.552469
# 13    70.463343
# 14    69.662651
# 15    79.580729
# 16    83.707959
# 17    83.429086
# 18    83.289338
# 19    82.939381
# 20    83.353879
# 21    82.994665
# Name: travelTime, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Hourly Trend Analysis
#
# - Early Morning (5 AM to 6 AM): Travel times are quick, most likely due to low traffic.
# - Morning Rush (7 a.m. to 9 a.m.): Travel times increase dramatically, peaking during these hours, which coincide with morning commute periods.
# - Midday (10 a.m. to 2 p.m.): Travel times reduce marginally but remain rather high, indicating ongoing congestion throughout the day.
# - Afternoon Rush (3 PM to 8 PM): Travel times are higher than in the morning rush, especially after 3 PM. This predicts more congestion during the evening commute.

# %% [markdown]
# - Perform geospatial Analysis to visualize the geographical distribution of the start and end points of trips with the longest and shortest travel times

# %%
import seaborn as sns

# Filter data to get the top 10% longest and shortest travel times for clearer visualization
quantile_90 = df['travelTime'].quantile(0.90)
longest_trips = df[df['travelTime'] >= quantile_90]
shortest_trips = df[df['travelTime'] <= df['travelTime'].quantile(0.10)]

# Setting up the figure for dual plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# Plotting longest trips
sns.scatterplot(data=longest_trips, x='tapInStopsLon', y='tapInStopsLat', size='travelTime', sizes=(20, 200), hue='travelTime', palette="viridis", legend=None, ax=ax1)
ax1.set_title('Geographic Distribution of Longest Trips')
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')
ax1.grid(True)

# Plotting shortest trips
sns.scatterplot(data=shortest_trips, x='tapInStopsLon', y='tapInStopsLat', size='travelTime', sizes=(20, 200), hue='travelTime', palette="cool", legend=None, ax=ax2)
ax2.set_title('Geographic Distribution of Shortest Trips')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')
ax2.grid(True)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# Geospatial Analysis
#
# - Longest Trips (Left Plot)     : Clusters show places with high congestion or long trips with multiple delays.
# - Shortest Trips (Right Plot)   : Even distribution indicates efficient traffic flow and shorter distances.
#
# Key Observations
# - Congestion Hotspots           : The longest trip clusters indicate places that require traffic management, such as improved flow or bus lanes.
# - Efficient locations are those with the shortest travels, which can serve as a model for improving crowded areas.

# %% [markdown]
# - Break down the routes into smaller pieces and find specific spots along the routes that contribute to the most delays.

# %%
# Redefine final_summary
final_summary = peak_route_stats.head(10)[['Average_Travel_Time', 'Trip_Count']].join(variability_stats[['mean', 'std']], how='left')

# Data for plotting high congestion routes
routes = final_summary.index
average_times = final_summary['Average_Travel_Time']
variability = final_summary['std']

fig, ax1 = plt.subplots(figsize=(8, 5))

# Bar plot for average travel times
color = 'tab:blue'
ax1.set_xlabel('Route Name')
ax1.set_ylabel('Average Travel Time (minutes)', color=color)
ax1.bar(routes, average_times, color=color, alpha=0.6, label='Average Travel Time')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(routes, rotation=45, ha="right")

# Line plot for variability on the same axis
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Standard Deviation of Travel Time (minutes)', color=color)
ax2.plot(routes, variability, color=color, marker='o', label='Travel Time Variability')
ax2.tick_params(axis='y', labelcolor=color)

# Title and legend
fig.tight_layout()
plt.title('Average Travel Time and Variability for Top Congested Routes')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

plt.show()
# Out:
# C:\Users\galuh\AppData\Local\Temp\ipykernel_15044\358843550.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(routes, rotation=45, ha="right")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>insights.:</b><br>
#
# This image highlights that routes such as "Pesanggrahan - Blok M" and "Stasiun Tebet - Karet via Underpass" have high average travel times and significant variability, making them ideal for targeted congestion management measures.

# %% [markdown]
# - Cause of Delays

# %%
# Correlation matrix for distance, travel time, and speed
correlation_matrix = congested_routes_df[['distance', 'travelTime', 'travelSpeed_KmpH']].corr()

# Plotting the correlation matrix
plt.figure(figsize=(8, 6))
plt.matshow(correlation_matrix, fignum=1, cmap='coolwarm')
plt.xticks(range(correlation_matrix.shape[1]), correlation_matrix.columns, rotation=45)
plt.yticks(range(correlation_matrix.shape[1]), correlation_matrix.columns)
plt.colorbar()
plt.title('Correlation Matrix for Distance, Travel Time, and Speed', pad=20)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Heatmap insights.:</b><br>
#
# Main Reasons for Delays and Extended Travel Times:
#
# Travel Speed: The substantial negative association between travel speed and trip time (-0.7) suggests that slower travel speeds are a key driver of longer travel times. Routes with slower speeds due to traffic congestion, frequent stops, or poor traffic management all contribute to lengthier travel times.
#
# Distance: The relatively modest association between distance and travel time (-0.03) indicates that route length is not a significant factor in causing delays. Other factors, such as the number and frequency of pauses and the presence of traffic signals, are more important.
#
# Traffic Flow and Stop Frequency: The moderate positive association between distance and travel speed (0.5) indicates that longer routes have greater speeds, maybe due to fewer stops or more efficient traffic flow in less congested locations. This finding implies that minimizing stop frequency and enhancing traffic flow can help reduce delays.
#
#
# <b>Key Implications:</b><br>
#
# Improving Travel Speeds: Dedicated bus lanes and traffic signal prioritization can reduce delays.
#
# Optimizing Stops: Reducing the number of stops on busy routes can improve travel speeds and save travel time.

# %%
#there are 30 days in April
days_in_month = 30


#filter tapout count groupby route and stop squences
tap_out_counts_month = df.groupby(['routeName', 'stopStartSeq']).size().reset_index(name='tapOutCount')


#Calculate average daily tapout
tap_out_counts_month['averageDailyCount'] = tap_out_counts_month['tapOutCount'] / days_in_month


#Total average daily tapout each route
total_average_counts = tap_out_counts_month.groupby('routeName')['averageDailyCount'].sum().reset_index()

# Identify the top 5 routes with the highest total average daily tap-out counts
top_routes = total_average_counts.sort_values(by='averageDailyCount', ascending=False).head(5)['routeName']

# Filter data for the top 5 routes
top_routes_data = tap_out_counts_month[tap_out_counts_month['routeName'].isin(top_routes)]

# Pivot the data to create a heatmap-friendly format
top_routes_heatmap_data = top_routes_data.pivot_table(index="routeName", columns="stopStartSeq", values="averageDailyCount", fill_value=0)

# Create the heatmap
plt.figure(figsize=(16, 5))
sns.heatmap(top_routes_heatmap_data, cmap="YlGnBu", annot=True, fmt=".2f", cbar_kws={'label': 'Average Daily Tap-Out Count'})
plt.title('Average Daily Tap-Out Count by Corridor and Stop Sequence for Top 10 Routes')
plt.xlabel('Stop Sequence')
plt.ylabel('Corridor Name')
plt.xticks(rotation=45, ha='right')
plt.show()


#there are 30 days in April
days_in_month = 30


#filter tapout count groupby route and stop squences
tap_in_count_month = df.groupby(['routeName', 'stopEndSeq']).size().reset_index(name='tapInCount')


#Calculate average daily tapout
tap_in_count_month['averageDailyCount'] = tap_in_count_month['tapInCount'] / days_in_month


#Total average daily tapout each route
total_avg_counts = tap_in_count_month.groupby('routeName')['averageDailyCount'].sum().reset_index()

# Identify the top 5 routes with the highest total average daily tap-out counts
top_route = total_avg_counts.sort_values(by='averageDailyCount', ascending=False).head(5)['routeName']

# Filter data for the top 5 routes
top_route_data = tap_in_count_month[tap_in_count_month['routeName'].isin(top_route)]

# Pivot the data to create a heatmap-friendly format
top_route_heatmap_data = top_route_data.pivot_table(index="routeName", columns="stopEndSeq", values="averageDailyCount", fill_value=0)

# Create the heatmap
plt.figure(figsize=(16, 5))
sns.heatmap(top_route_heatmap_data, cmap="YlGnBu", annot=True, fmt=".2f", cbar_kws={'label': 'Average Daily Tap-Out Count'})
plt.title('Average Daily Tap-In Count by Corridor and Stop Sequence for Top 10 Routes')
plt.xlabel('Stop Sequence')
plt.ylabel('Corridor Name')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Heatmap insights.:</b><br>
#
#
# Tap Out Stations (Top Heatmap)
#
# - Cibubur - Balai Kota (Stop Sequence 0): has a high average daily tap-out count (2.60), indicating a popular disembarkation site.
# - Kalideres - Bundaran HI via Veteran (Stop Sequence 11): Another high volume tap-out point (2.13), indicating that this is an important stop for disembarking passengers.
# - Tap-Out Volumes: Average daily tap-out counts range from medium to low across several routes. These include intermediate stops along routes such as Harmoni-Jakarta International Stadium and Pulo Gadung-Monas.
#
#
# Tap-in Stations (Bottom Heatmap)
#
# - Harmoni - Jakarta International Stadium (Stop Sequence 11) has a high average daily tap-in count of 4.17, indicating a prominent boarding point.
# - Cibubur - Balai Kota (Stop Sequence 10): Another high volume tap-in point (2.57), indicating that it is an important stop for passengers boarding the bus.
# - Tap-in volumes range from medium to low, similar to tap-out volumes, at different stops. These trends can be seen at intermediate stops along routes such as Ciputat - CSW and Kalideres - Bundaran HI via Veteran.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:darkturquoise'>Section 5 |</span><span style='color:darkblue'> Conclusion & Recommendation</span></b>
#
# ____
# This section summarizes the important findings of our analysis.
#
# - High Congestion Routes: The routes with the longest average travel time during peak hours were found.
# These include: Pesanggrahan - Blok M and Stasiun Tebet - Karet via Underpass, Rusun Jati Rawasari, Senen
#
# - Causes of Delays: The study found that slower travel speeds are connected with longer travel times, particularly during peak hours. Travel times varied greatly, especially on some stretches of the more busy routes.
#
# - Travel Time Variability: Routes such as "Stasiun Tebet - Karet via Underpass" and "Kebayoran Lama - Tanah Abang" had considerable variability in travel times, indicating inconsistent service that could harm consumer satisfaction.
#
# - Geospatial Congestion: Certain geographic groupings were identified as congestion hotspots, indicating which locations could benefit from focused traffic management and infrastructural improvements.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Conclusion:</b><br>
#
# Based on our thorough examination of Transjakarta's operational data, we can answer critical questions and provide extensive insights and recommendations to improve operational efficiency and customer satisfaction.
#
# Key Questions and Detailed Findings:
#
# 1. Which routes have the most congestion and take the longest to travel during peak hours?
# Routes identified:
# - Cibubur - Balai Kota: This route has consistently shown significant congestion and extended travel times, especially during peak hours.
# - Ciputat - CSW: Another route with heavy traffic, particularly at major points.
# - Kalideres - Bundaran HI via Veteran: Heavy traffic and lengthier journey times.
#
# Heatmap insights:
# These routes were emphasized in the heatmap due to greater average daily tap-out and tap-in counts at numerous important stops, indicating increased traffic and congestion.
#
# 2. What are the primary reasons for delays and longer travel times on these routes?
# - Correlation Analysis shows a high correlation between lower travel speeds and longer trip times, particularly during peak hours. Travel times varied greatly, particularly on some of the most busy routes.
# - Geospatial analysis found congestion hotspots, highlighting areas for targeted traffic management and infrastructure improvements.
# - High passenger volumes, road congestion, and frequent stops in high-traffic areas were common causes of delays.
#
# 3. How does travel time variability impact customer satisfaction and service dependability?
# - Routes such as "Stasiun Tebet - Karet via Underpass" and "Kebayoran Lama - Tanah Abang" have substantial fluctuation in travel times, indicating unreliable service.
# - High variability in journey durations might reduce customer satisfaction owing to unpredictability and longer wait periods.
# - Service Dependability: Inconsistent travel times make it difficult for passengers to plan their journeys accurately.
#
# 4. What modifications may be made to optimize route efficiency and handle peak hour demand more effectively?
# - Enhanced Infrastructure: Invest in better amenities at high-activity stops to manage high passenger loads efficiently.
# - Real-time data allows for dynamic resource allocation, adjusting bus numbers and frequency based on passenger volume.
# - Optimize low-activity stops by omitting or reducing service frequency to optimize route efficiency.
# - The heatmap detected stations with low average daily tap-in and tap-out counts. These stations should be assessed for potential skipping during busy hours to improve efficiency.
# - Prioritize traffic signal optimization and dedicated bus lanes to reduce congestion on top routes.
# - Implement segment-specific measures to address identified congestion hotspots.
# - Passenger Communication: Maintain clear and timely communication with passengers about any changes in stop frequencies or itineraries.
#
#
#
#
#
# <b>Recommendation:</b><br>
# - Improve infrastructure at high-activity stops, such as Cibubur-Balai Kota and Harmoni-Jakarta International Stadium, to accommodate high passenger loads.
# - Real-time monitoring allows for dynamic resource allocation based on passenger statistics.
# - Optimize route efficiency by skipping low-activity stops during peak hours to save travel time and congestion.
# - Traffic Management: Work with city traffic management to optimize traffic signals and add dedicated bus lanes in high-traffic locations.
# - Gather and implement passenger feedback to ensure modifications suit their needs and increase happiness.
# - Transjakarta's implementation of these strategies can significantly improve route efficiency, reduce travel time variability, and increase overall customer satisfaction.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Simulating Success Criteria:</b><br>
#
#
# 1. Reduced Travel Time
#
# Goal: Reduce average travel times by 10% on the most congested routes during peak hours.
#
# Let's take the route Kampung Rambutan - Blok M, which has the longest average journey time.
# Current average travel time is 80 minutes.
# The target average travel time (10% reduction) is 72 minutes.
#
# Strategies for meeting the criteria:
# - Dedicated Bus Lanes: Implementing dedicated bus lanes can eliminate interference from other traffic, leading to faster travel times.
# - For instance, if buses now average 20 km/h in mixed traffic, dedicated lanes might boost this to 25 km/h.
#
# Adjusted Bus Schedules:
# - Adding 2 more buses per hour during peak hours can reduce passenger loading times and minimize delays at each stop.
# - Optimized Stop Frequency: Reducing stops from 15 to 10 can save approximately 1 minute per stop, resulting in a 5 minute overall travel time reduction.
#
#
# 2. Increased consistency.
#
# Goal: Reduce travel time variability by 15%, resulting in more predictable and reliable service.
#
# onsider the route Stasiun Tebet - Karet via Underpass, which has a large standard deviation in trip times.
# Current variability (standard deviation) is 30 minutes.
# Target Variability (15% Reduction) is 25.5 minutes.
#
# Strategies for meeting the criteria:
# - Real-Time Traffic Management: Using real-time data to manage bus dispatch can help to prevent bunching and ensure even spacing.
# - For example, altering dispatch schedules based on current traffic can help to smooth out travel times.
#
# Traffic Signal Prioritization:
# - Giving buses priority at traffic signals can help to reduce pauses and delays.
# - Prioritization can reduce the average time spent by buses at signals from 5 to 3 minutes, reducing variability.
#
# Consistent Scheduling:
# - By standardizing the time spent at each stop (e.g., 30 seconds per stop), better boarding procedures and personnel training can improve travel time predictability.
#
# 3. Operational Efficiency
#
# Goal: Make at least three operational adjustments that contribute to the improvements listed above.
#
# Simulation:
# - Change 1: Dynamic Scheduling Integrate real-time data to change bus schedules.
# Impact: Reduces wait times and improves bus distribution, resulting in a 5% reduction in travel time and a 10% boost in service reliability.
#
# - Change 2: Route Optimization
# Implementation: Avoid low-activity stops during peak hours.
# mpact: Reduces travel time by 10% on specific routes and reduces variability by requiring fewer stops.
#
# - Change 3: Traffic Management Solutions
# Implementation: Implement dedicated bus lanes and traffic signal prioritization.
# Impact: Increases average bus speed by 20%, reducing overall travel time by up to 15 minutes on congested routes, and decreases variability by 10%.
#
# 4. Increased On-Time Performance
#
# Goal: Improve on-time performance by 15% on busy routes during peak hours. For example, the Kampung Rambutan - Blok M route now has a 70% on-time rate. A 15% improvement would bring this to 80.5%.
#
# Strategies:
# - Optimized stop frequency:
# Skipping low-activity stops can cut the number of stops per journey.
# For example, lowering stops from 15 to 10 can save about 1 minute every stop, reducing overall travel time by 5 minutes and allowing buses to stay on time.
